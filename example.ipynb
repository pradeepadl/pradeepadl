# %%
Breadth = input("Enter a list of numbers separated by spaces: ").split()
numbers = [int(num) for num in Breadth]
squared_numbers = [num ** 2 for num in numbers]
print("Squared numbers:", squared_numbers)
# Out:
# Squared numbers: [36]

# %%
import math 
num=25
sqrt_num = math.sqrt(625)/num
print("The square root of 625 divided by", num, "is:", sqrt_num)
print(bool(14),bool(),bool(1+2),bool(0))
x=10
y=5
result=x%y
print("The result of the operation is:", result)
# Out:
# The square root of 625 divided by 25 is: 1.0
# True False True False
# The result of the operation is: 0
