# %%
tracking_ids = ['PKG123', 'PKG456', 'PKG789']
tracking_statuses = ['In Transit', 'Delivered', 'Out for Delivery']
for tracking_id, status in zip(tracking_ids, tracking_statuses):
    print(f"Package {tracking_id} is currently: {status}")
# Out:
# Package PKG123 is currently: In Transit
# Package PKG456 is currently: Delivered
# Package PKG789 is currently: Out for Delivery
